# %%
# Task 1
from matplotlib import pyplot as plt
students = ['s1', 's2', 's3','s4','s5','s6','s7','s8','s9','s10']
heights = [4.2,3.5,4.6,4,4,3.9,6,5.8,4.7,3.8]
plt.bar(students,heights)
plt.xlabel('students')
plt.ylabel('height')
plt.show()

# %%
from matplotlib import pyplot as plt
students = ['s1', 's2', 's3','s4','s5','s6','s7','s8','s9','s10']
heights = [4.2,3.5,4.6,4,4,3.9,6,5.8,4.7,3.8]
plt.xlabel('students')
plt.ylabel('height')
plt.pie(heights,labels=students)
plt.show()

# %%
# Task 2
from matplotlib import pyplot as plt
cities =['A','B','C','D','E','F','G','H','I','J']
population = [15,20,30,48,23,73,27,39,63,14]
#plt.hist(population,color="o",bins=cities,edgecolor="p",orientation="horizontal")
plt.barh(cities,population,color="r")
plt.xlabel('Population')
plt.ylabel('Cities')
plt.title('Cities / Population Horizontal Bar Graph')
plt.show()

# %%
# Task 3
from matplotlib import pyplot as plt
icecream = ['Vanila','Chocolate','Mango','Strawberry','Pineapple']
scoops =[10,15,25,30,20]
plt.pie(scoops,labels=icecream)
plt.show()

# %%
# Task 4
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
file_path = 'students_info.csv'
data = pd .read_csv(file_path)
first_20_values = data['Age'][:20]
print(first_20_values)
def groupage(age):
    if age >= 18 and age <= 25:
        return '18-25'
    elif age >= 26 and age <= 30:
        return '26-30'
    else:
        return '30+'
first_20_values = first_20_values.apply(groupage)
agecount = first_20_values.value_counts()
plt.pie(agecount, labels = agecount.index)
plt.show()
# Out:
# 0     19
# 1     18
# 2     23
# 3     19
# 4     21
# 5     21
# 6     22
# 7     25
# 8     24
# 9     21
# 10    19
# 11    22
# 12    24
# 13    24
# 14    18
# 15    23
# 16    18
# 17    18
# 18    23
# 19    20
# Name: Age, dtype: int64

# %%
#Task 5
import matplotlib.pyplot as plt

gender_labels = ['Male', 'Female']
gender_counts = [36, 50]  

plt.pie(gender_counts, labels=gender_labels, startangle=140, colors=['red', 'blue'])
plt.axis('equal')  
plt.title('Gender Distribution Among Students')

plt.show()

# %%
#Task 6
import matplotlib.pyplot as plt

students = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10']
math_marks = [56, 80, 55, 47, 89, 28, 76, 38, 18, 80]
science_marks = [42, 25, 33, 92, 91, 22, 38, 60, 27, 94]
plt.scatter(math_marks, science_marks, label='Marks')
plt.xlabel('Mathematics Marks')
plt.ylabel('Science Marks')
plt.title('Mathematics vs. Science Marks')
plt.legend()

for i, student in enumerate(students):
    plt.annotate(student, (math_marks[i], science_marks[i]))

plt.show()

# %%
import matplotlib.pyplot as plt

years = [
    1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889,
    1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899,
    1900
]

sea_levels = [
    0, 0.220472441, -0.440944881, -0.232283464, 0.590551181, 0.531496062, 0.437007874, 
    0.216535433, 0.299212598, 0.362204724, 0.440944881, 0.374015748, 0.499999999, 
    0.685039369, 0.303149606, 0.767716535, 0.468503937, 0.673228346, 1.043307086, 
    1.338582676, 1.125984251
]

lower_bound = [
    -0.952755905, -0.732283464, -1.346456692, -1.129921259, -0.283464567, -0.330708661, 
    -0.381889763, -0.602362204, -0.519685039, -0.456692913, -0.374015748, -0.440944881, 
    -0.31496063, -0.114173228, -0.547244094, -0.082677165, -0.366141732, -0.145669291, 
    0.267716535, 0.574803149, 0.405511811
]

upper_bound = [
    0.952755905, 1.173228345, 0.464566929, 0.66535433, 1.464566928, 1.393700786, 1.255905511, 
    1.03543307, 1.118110235, 1.181102361, 1.255905511, 1.188976377, 1.314960629, 
    1.484251967, 1.153543306, 1.618110235, 1.303149605, 1.492125983, 1.818897636, 
    2.102362203, 1.846456691
]

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(years, sea_levels, color='b', label='Sea Level')
plt.fill_between(years, lower_bound, upper_bound, color='gray', alpha=0.5, label='Uncertainty Range')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Sea Level Rise Over the First 100 Years')
plt.legend()
plt.grid(True)
plt.show()
